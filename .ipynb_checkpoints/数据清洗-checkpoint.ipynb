# %%
#导入数据库+读数据
import pandas as pd

# 改成你的原始文件名
raw_path = "2022_LoL_esports_match_data_from_OraclesElixir.csv"

df = pd.read_csv(raw_path)

print(df.shape)
df.head()
# Out:
# C:\Users\32144\AppData\Local\Temp\ipykernel_14572\3424922830.py:6: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(raw_path)
# (150588, 161)
#                   gameid datacompleteness  url league  year   split  playoffs  \
# 0  ESPORTSTMNT01_2690210         complete  NaN   LCKC  2022  Spring         0
# 1  ESPORTSTMNT01_2690210         complete  NaN   LCKC  2022  Spring         0
# 2  ESPORTSTMNT01_2690210         complete  NaN   LCKC  2022  Spring         0
# 3  ESPORTSTMNT01_2690210         complete  NaN   LCKC  2022  Spring         0
# 4  ESPORTSTMNT01_2690210         complete  NaN   LCKC  2022  Spring         0
#
#                   date  game  patch  ...  opp_csat25 golddiffat25 xpdiffat25  \
# 0  2022-01-10 07:44:08     1  12.01  ...       203.0        605.0     -525.0
# 1  2022-01-10 07:44:08     1  12.01  ...       163.0        421.0     -903.0
# ...

# %%
df.columns.tolist()
# Out:
# ['gameid',
#  'datacompleteness',
#  'url',
#  'league',
#  'year',
#  'split',
#  'playoffs',
#  'date',
#  'game',
#  'patch',
#  'participantid',
#  'side',
#  'position',
#  'playername',
#  'playerid',
#  'teamname',
#  'teamid',
#  'champion',
#  'ban1',
#  'ban2',
#  'ban3',
#  'ban4',
#  'ban5',
#  'pick1',
#  'pick2',
#  'pick3',
#  'pick4',
#  'pick5',
#  'gamelength',
#  'result',
#  'kills',
#  'deaths',
#  'assists',
#  'teamkills',
#  'teamdeaths',
#  'doublekills',
#  'triplekills',
#  'quadrakills',
#  'pentakills',
#  'firstblood',
#  'firstbloodkill',
#  'firstbloodassist',
#  'firstbloodvictim',
#  'team kpm',
#  'ckpm',
#  'firstdragon',
#  'dragons',
#  'opp_dragons',
#  'elementaldrakes',
#  'opp_elementaldrakes',
#  'infernals',
#  'mountains',
#  'clouds',
#  'oceans',
#  'chemtechs',
#  'hextechs',
#  'dragons (type unknown)',
#  'elders',
#  'opp_elders',
#  'firstherald',
#  'heralds',
#  'opp_heralds',
#  'void_grubs',
#  'opp_void_grubs',
# ...

# %%
#result 里面是什么值（等下要把它变成 win/lose）
df["result"].value_counts(dropna=False)
# Out:
# result
# 0    75294
# 1    75294
# Name: count, dtype: int64

# %%
#保留我们需要的列

# %%
use_cols = [
    "gameid",
    "league",
    "year",
    "patch",
    "side",
    "teamname",
    "datacompleteness",
    "result",
    
    # 1. 前10分钟经济差
    "golddiffat10",
    
    # 2. 小龙
    "firstdragon",
    "dragons",
    "opp_dragons",
    
    # 3. 男爵
    "firstbaron",
    "barons",
    "opp_barons",
    
    # 4. 推塔
    "towers",
    "opp_towers",
    
    # 5. 视野
    "visionscore",
    "vspm",
    
    # 6. 可选：前10分钟击杀差
    "killsat10",
    "opp_killsat10"
]

# 如果有些列名不在，就先打印出来看一下
missing = [c for c in use_cols if c not in df.columns]
print("缺失的列：", missing)

# 只在列存在时才保留，保证不会直接报错
use_cols_existing = [c for c in use_cols if c in df.columns]

df_small = df[use_cols_existing].copy()

print(df_small.shape)
df_small.head()
# Out:
# 缺失的列： []
# (150588, 21)
#                   gameid league  year  patch  side           teamname  \
# 0  ESPORTSTMNT01_2690210   LCKC  2022  12.01  Blue  BRION Challengers
# 1  ESPORTSTMNT01_2690210   LCKC  2022  12.01  Blue  BRION Challengers
# 2  ESPORTSTMNT01_2690210   LCKC  2022  12.01  Blue  BRION Challengers
# 3  ESPORTSTMNT01_2690210   LCKC  2022  12.01  Blue  BRION Challengers
# 4  ESPORTSTMNT01_2690210   LCKC  2022  12.01  Blue  BRION Challengers
#
#   datacompleteness  result  golddiffat10  firstdragon  ...  opp_dragons  \
# 0         complete       0          52.0          NaN  ...          NaN
# 1         complete       0         485.0          NaN  ...          NaN
# 2         complete       0         162.0          NaN  ...          NaN
# 3         complete       0         296.0          NaN  ...          NaN
# 4         complete       0         528.0          NaN  ...          NaN
#
#    firstbaron  barons  opp_barons  towers  opp_towers  visionscore    vspm  \
# ...

# %%
#过滤完整对局

# %%
# 只保留 datacompleteness 是 "complete" 的行（如果有这一列）
if "datacompleteness" in df_small.columns:
    print(df_small["datacompleteness"].value_counts(dropna=False))
    df_small = df_small[df_small["datacompleteness"] == "complete"]

# 去掉没有 result 的行
df_small = df_small.dropna(subset=["result"])

print(df_small.shape)
df_small.head()
# Out:
# datacompleteness
# complete    127872
# partial      22716
# Name: count, dtype: int64
# (127872, 21)
#                   gameid league  year  patch  side           teamname  \
# 0  ESPORTSTMNT01_2690210   LCKC  2022  12.01  Blue  BRION Challengers
# 1  ESPORTSTMNT01_2690210   LCKC  2022  12.01  Blue  BRION Challengers
# 2  ESPORTSTMNT01_2690210   LCKC  2022  12.01  Blue  BRION Challengers
# 3  ESPORTSTMNT01_2690210   LCKC  2022  12.01  Blue  BRION Challengers
# 4  ESPORTSTMNT01_2690210   LCKC  2022  12.01  Blue  BRION Challengers
#
#   datacompleteness  result  golddiffat10  firstdragon  ...  opp_dragons  \
# 0         complete       0          52.0          NaN  ...          NaN
# 1         complete       0         485.0          NaN  ...          NaN
# 2         complete       0         162.0          NaN  ...          NaN
# 3         complete       0         296.0          NaN  ...          NaN
# 4         complete       0         528.0          NaN  ...          NaN
#
# ...

# %%
df_small["win"] = df_small["result"].astype(int)
df_small["win"].value_counts(dropna=False)
# Out:
# win
# 0    63936
# 1    63936
# Name: count, dtype: int64

# %%
#从“选手级”合并到“队伍级”（每队每局一行）

#现在每一行是一名选手，我们要按 gameid + side 合并成“某队在某一局”

# %%
group_cols = ["gameid", "side"]

agg_dict = {
    "league": "first",
    "year": "first",
    "patch": "first",
    "teamname": "first",
    "datacompleteness": "first",
    "result": "first",
    "win": "first",
    
    # 前10分钟经济差
    "golddiffat10": "first",
    
    # 小龙
    "firstdragon": "first",
    "dragons": "first",
    "opp_dragons": "first",
    
    # 男爵
    "firstbaron": "first",
    "barons": "first",
    "opp_barons": "first",
    
    # 推塔
    "towers": "first",
    "opp_towers": "first",
    
    # 视野：队伍总和
    "visionscore": "sum",
    "vspm": "sum",
    
    # 可选：前10分钟击杀差
    "killsat10": "first",
    "opp_killsat10": "first",
}

team_df = df_small.groupby(group_cols).agg(agg_dict).reset_index()

print(team_df.shape)
team_df.head()
#现在 team_df 的每一行就是：

#某一局 + 某一边（blue/red） 的队伍整体数据
# Out:
# (21312, 22)
#                   gameid  side league  year  patch                  teamname  \
# 0  ESPORTSTMNT01_2690210  Blue   LCKC  2022  12.01         BRION Challengers
# 1  ESPORTSTMNT01_2690210   Red   LCKC  2022  12.01  Nongshim Esports Academy
# 2  ESPORTSTMNT01_2690219  Blue   LCKC  2022  12.01        T1 Esports Academy
# 3  ESPORTSTMNT01_2690219   Red   LCKC  2022  12.01        Liiv SANDBOX Youth
# 4  ESPORTSTMNT01_2690227  Blue   LCKC  2022  12.01    KT Rolster Challengers
#
#   datacompleteness  result  win  golddiffat10  ...  opp_dragons  firstbaron  \
# 0         complete       0    0          52.0  ...          3.0         0.0
# 1         complete       1    1         -52.0  ...          1.0         0.0
# 2         complete       0    0        -894.0  ...          4.0         0.0
# 3         complete       1    1         894.0  ...          1.0         1.0
# 4         complete       1    1          53.0  ...          1.0         1.0
#
# ...

# %%
#假如几个衍生字段
#目的是为了更方便做图：加入tower_diff：推塔差 team_vspm：全队视野强度  kills_diff_10：前 10 分钟击杀差

# %%
# 推塔差
team_df["tower_diff"] = team_df["towers"] - team_df["opp_towers"]

# 视野强度：直接用队伍总 vspm
team_df["team_vspm"] = team_df["vspm"]

# 前10分钟击杀差
if "killsat10" in team_df.columns and "opp_killsat10" in team_df.columns:
    team_df["kills_diff_10"] = team_df["killsat10"] - team_df["opp_killsat10"]

team_df.head()
# Out:
#                   gameid  side league  year  patch                  teamname  \
# 0  ESPORTSTMNT01_2690210  Blue   LCKC  2022  12.01         BRION Challengers
# 1  ESPORTSTMNT01_2690210   Red   LCKC  2022  12.01  Nongshim Esports Academy
# 2  ESPORTSTMNT01_2690219  Blue   LCKC  2022  12.01        T1 Esports Academy
# 3  ESPORTSTMNT01_2690219   Red   LCKC  2022  12.01        Liiv SANDBOX Youth
# 4  ESPORTSTMNT01_2690227  Blue   LCKC  2022  12.01    KT Rolster Challengers
#
#   datacompleteness  result  win  golddiffat10  ...  opp_barons  towers  \
# 0         complete       0    0          52.0  ...         0.0     3.0
# 1         complete       1    1         -52.0  ...         0.0     6.0
# 2         complete       0    0        -894.0  ...         0.0     3.0
# 3         complete       1    1         894.0  ...         0.0    11.0
# 4         complete       1    1          53.0  ...         0.0    11.0
#
# ...

# %%
clean_path = "lol_team_clean.csv"
team_df.to_csv(clean_path, index=False)
clean_path
# Out:
# 'lol_team_clean.csv'
